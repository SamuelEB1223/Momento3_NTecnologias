# %%
# !pip install pandas

# %%
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
hotel_bookings= pd.read_excel("/content/drive/MyDrive/Colab Notebooks/hotel_bookings.xlsx")
hotel_bookings.shape
# Out:
# (119390, 32)

# %%
hotel_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
hotel_bookings.dtypes
# Out:
# hotel                                     object
# is_canceled                                int64
# lead_time                                  int64
# arrival_date_year                          int64
# arrival_date_month                        object
# arrival_date_week_number                   int64
# arrival_date_day_of_month                  int64
# stays_in_weekend_nights                    int64
# stays_in_week_nights                       int64
# adults                                     int64
# children                                 float64
# babies                                     int64
# meal                                      object
# country                                   object
# market_segment                            object
# distribution_channel                      object
# is_repeated_guest                          int64
# previous_cancellations                     int64
# previous_bookings_not_canceled             int64
# ...

# %%
hotel_bookings.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
hotel_bookings[["children","country","market_segment"]]
# Out:
#         children country market_segment
# 0            0.0     PRT         Direct
# 1            0.0     PRT         Direct
# 2            0.0     GBR         Direct
# 3            0.0     GBR      Corporate
# 4            0.0     GBR      Online TA
# ...          ...     ...            ...
# 119385       0.0     BEL  Offline TA/TO
# 119386       0.0     FRA      Online TA
# 119387       0.0     DEU      Online TA
# 119388       0.0     GBR      Online TA
# 119389       0.0     DEU      Online TA
#
# [119390 rows x 3 columns]

# %%
sel_PRT= hotel_bookings ['country']=="PRT"
cant_Pr = hotel_bookings [sel_PRT]. shape[0]
cant_Pr
# Out:
# 48590

# %%
country = ['PRT', 'GBR','FRA','DEU','BEL']
seleccion = 'PRT'in (country)
hotel_bookings = country[seleccion]

# %%
sel_Resor_Hotel= hotel_bookings["hotel"]== "ResorHotel"
cant_RH = hotel_bookings [~sel_Resor_Hotel]. shape[0]
cant_RH
# Out:
# 119390

# %%
list(hotel_bookings['hotel'].drop_duplicates())
# Out:
# ['Resort Hotel', 'City Hotel']

# %%
list (hotel_bookings['country'].drop_duplicates())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-b5451fa6eae7> in <cell line: 1>()
# ----> 1 list (hotel_bookings['country'].drop_duplicates())
#
# TypeError: string indices must be integers

# %%
hotel_bookings.isnul
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-7888bbc3e16c> in <cell line: 1>()
# ----> 1 hotel_bookings.isnul
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'isnul'
